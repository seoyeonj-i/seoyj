# %% [markdown]
# # 웹 크롤링
# 1. 사용할 라이브러리 목록
#     - requests
#     - bs4 (BeautifuSoup)
#         - bs4 라이브러리안에있는 BeautifulSoup class
#         - html 문서형 데이터를 pasing을하여 데이터를쉽게 추출할 수있도록 도와주는 라이브러리
#         - html의 TAG를 기준으로 데이터를 추출
#         - 웹의 구조를 어느정도 인지하고 사용한다면 쉽게 접근 가능
#         - parser를 활용해서 파이썬에서 접근이 쉽게 객체형태로 제공
#     - selenium
#         - 웹 어플리케이션을 테스트 하기위해 만들어진 라이브러리
#         - 웹 브라우저를 파이썬의코드를 이용하여 제어
#         - 크롬이 구버전이거나 selmium이 구버전인 경우에는 별도의 소프트웨어를 설치

# %%
import requests

# %%
url="https://www.naver.com"

# %%
response=requests.get(url)

# %%
html_data=response.text

# %%
type(html_data)
# Out:
# str

# %%
html_data[378:410]
# Out:
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
html_data.find('네이버')
# Out:
# 378

# %%
# !pip install bs4
# Out:
# ...
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup as bs

# %%
# pasing 작업 : 데이터의 형태를 변환
# (새로운 class에 인자값을 대입하여 새로운 객체 생성)
soup = bs(html_data, 'html.parser')

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
# ...

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %% [markdown]
# - 태그의 이름을 기준으로 검색
#     - soup.태그명 : HTML 문서에서 해당 태그명의 첫번째 정보를 출력
#     - soup.태그명.string : 첫번째 태그 정보에서 문자열이 출력
#     - soup.태그명['속성명] : 첫번째 태그 정보에서 속성의 값이 출력

# %%
# 네이버에서 a태그(하이퍼링크) 중 첫번째 태그를 확인
soup.a
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.a.string
# Out:
# '상단영역 바로가기'

# %%
soup.a['href']
# Out:
# '#topAsideButton'

# %% [markdown]
# - find({태그명})
#     - HTML 문자열에서 해당 태그의 첫번째 정보를 출력
#     - find(속성명=속성값) : 태그 들 중에 해당 속성을 가지고 있는 태그의 첫번째 태그의 정보를 출력
# - find_all({태그명})
#     - HTML 문자열에서 해당 태그의 모든 태그 정보를 리스트의 형태로 출력
#     - limit 매개변수 : 리스트의 개수를 지정

# %%
first_a=soup.find('a')

# %%
type(first_a)
# Out:
# bs4.element.Tag

# %%
a_list=soup.find_all('a')

# %%
type(a_list)
# Out:
# bs4.element.ResultSet

# %%
print(first_a)
print(a_list)
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>
# ...

# %%
first_a.get_text()
# Out:
# '상단영역 바로가기'

# %%
a_list[1].get_text()
# Out:
# '서비스 메뉴 바로가기'

# %%
data_list=[]

for i in a_list:
    print(i.get_text()) # 겟텍스트 대신 .string 사용해도 같은 결과
    data_list.append(i.get_text())
# Out:
# 상단영역 바로가기
# 서비스 메뉴 바로가기
# 새소식 블록 바로가기
# 쇼핑 블록 바로가기
# 관심사 블록 바로가기
# MY 영역 바로가기
# 위젯 보드 바로가기
# 보기 설정 바로가기
# 전체삭제
# 도움말
# 도움말
# 자동저장 끄기
# 도움말
# 닫기
# 이 정보가 표시된 이유
# 레이어 닫기
# 자세히보기
# 관심사를 반영한 컨텍스트 자동완성도움말
# 컨텍스트 자동완성
# 자세히 보기
# 자세히 보기
# 네이버로그인
# 컨텍스트 자동완성 레이어 닫기
# 자동완성 끄기
# 도움말
# 신고
# 닫기

# %%
data_list
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기',
#  '전체삭제',
#  '도움말',
#  '도움말',
#  '자동저장 끄기',
#  '도움말',
#  '닫기',
#  '이 정보가 표시된 이유',
#  '레이어 닫기',
#  '자세히보기',
#  '관심사를 반영한 컨텍스트 자동완성도움말',
#  '컨텍스트 자동완성',
#  '자세히 보기',
#  '자세히 보기',
#  '네이버로그인',
#  '컨텍스트 자동완성 레이어 닫기',
#  '자동완성 끄기',
#  '도움말',
#  '신고',
#  '닫기']

# %%
# 네이버 파이낸스 페이지에서 데이터 크롤링
url='https://finance.naver.com/'
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
html_data=response.text

# %%
# Beautifulsoup의 데이터 형으로 파싱
soup=bs(html_data, 'html.parser')

# %%
soup
# Out:
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title">
# <meta content="네이버페이 증권" property="og:title">
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240219184628/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
# 크롤링하고자하는 사이트에서 F12 -> 상단 제일 위 캡쳐같이 생긴거누르면 위치를 찾을 수있음

# %%
# soup에서 table 태그들 중 class의 값이 tb1_home 태그를 선택
len(soup.find_all('table', attrs={
    'class':'tbl_home'
}))
# Out:
# 12

# %%
# 길이확인
len(soup.find_all('div',attrs={'class':'section_sise_top'}))
# Out:
# 1

# %%
div_data=soup.find('div',attrs={'class':'section_sise_top'})

# %%
div_data2=soup.find('div',attrs={'class':'section_sise_top'}) #print(type(div_data[0]))으로 사용해야 find와 동일

# %%
print(type(div_data))
# Out:
# <class 'bs4.element.Tag'>

# %%
div_data
# Out:
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <ul class="tab_area sise_top1">
# <li class="tab1"><a class="is_active" href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;"><span>거래상위</span></a></li>
# <li class="tab2"><a href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span>상승</span></a></li>
# <li class="tab3"><a href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span>하락</span></a></li>
# <li class="tab4"><a href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span>시가총액 상위</span></a></li>
# </ul>
# <div class="group_type is_active">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# ...

# %%
len(div_data.find_all('table', attrs={'class':'tbl_home'}))
# 같은 디자인의 테이블이 4개가 있는 것을 확인할 수있음(거래상위, 상승, 하락, 시가총액상위)
# Out:
# 4

# %%
tables=div_data.find_all('table', attrs={'class':'tbl_home'})

# %%
tables[0]
# Out:
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=032680" onclick="clickcr(this, 'spe.slist', '032680', '1', event);">소프트센</a></th>
# <td>852</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 36</td>
# <td>
# <em class="up">
# 				+4.41%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=033170" onclick="clickcr(this, 'spe.slist', '033170', '2', event);">시그네틱스</a></th>
# <td>1,981</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 182</td>
# <td>
# <em class="up">
# 				+10.12%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# ...

# %%
tables[0].tr
# Out:
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>

# %%
tables[0].find('tr')
# Out:
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>

# %%
tables[0].find('tr').get_text().split()
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
th_list=tables[0].find('tr').find_all('th')

_cols=[]

for i in th_list:
    _cols.append(i.get_text())
_cols
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
trade_top=tables[0]

# %%
tr_list=trade_top.find_all('tr')

# %%
tr_list[1]
# Out:
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=032680" onclick="clickcr(this, 'spe.slist', '032680', '1', event);">소프트센</a></th>
# <td>852</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 36</td>
# <td>
# <em class="up">
# 				+4.41%
# 				</em>
# </td>
# </tr>

# %%
tr_list[1].get_text().split()
# Out:
# ['소프트센', '852', '상승', '36', '+4.41%']

# %%
# 결과를 보면 상승과 36이 따로 쪼개져서 나옴-> for문 이용
_val=[tr_list[1].find('th').get_text()]

td_list=tr_list[1].find_all('td')
# td_list

for i in td_list:
    data=i.get_text().strip()
    _val.append(data)
_val
# Out:
# ['소프트센', '852', '상승 36', '+4.41%']

# %%
_values=[]

for i in range(1, len(tr_list)):
    _val=[tr_list[i].find('th').get_text()]

    td_list=tr_list[i].find_all('td')

    for j in td_list:
        data=j.get_text().strip()
        _val.append(data)

    _values.append(_val)
_values
# Out:
# [['소프트센', '852', '상승 36', '+4.41%'],
#  ['시그네틱스', '1,981', '상승 182', '+10.12%'],
#  ['KODEX 200선물인버스2X', '2,220', '하락 15', '-0.67%'],
#  ['씨씨에스', '5,750', '상승 250', '+4.55%'],
#  ['베셀', '705', '상승 162', '+29.83%'],
#  ['KR모터스', '527', '상승 30', '+6.04%'],
#  ['KODEX 코스닥150선물인버스', '3,615', '상승 5', '+0.14%'],
#  ['인성정보', '5,320', '하락 40', '-0.75%'],
#  ['골든센츄리', '143', '하락 8', '-5.30%'],
#  ['아이비김영', '2,535', '상승 485', '+23.66%'],
#  ['리노스', '1,906', '상승 116', '+6.48%'],
#  ['케이웨더', '18,620', '상승 11,620', '+166.00%'],
#  ['유비케어', '6,470', '상승 420', '+6.94%'],
#  ['디딤이앤에프', '602', '상승 95', '+18.74%'],
#  ['카나리아바이오', '1,133', '하락 133', '-10.51%']]

# %%
import pandas as pd
# Out:
# C:\Users\82105\AppData\Local\Temp\ipykernel_100384\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.DataFrame(_values)

# %%
df.columns=_cols

# %%
df
# Out:
#                   종목명     현재가       전일대비       등락률
# 0                소프트센     852      상승 36    +4.41%
# 1               시그네틱스   1,981     상승 182   +10.12%
# 2    KODEX 200선물인버스2X   2,220      하락 15    -0.67%
# 3                씨씨에스   5,750     상승 250    +4.55%
# 4                  베셀     705     상승 162   +29.83%
# 5               KR모터스     527      상승 30    +6.04%
# 6   KODEX 코스닥150선물인버스   3,615       상승 5    +0.14%
# 7                인성정보   5,320      하락 40    -0.75%
# 8               골든센츄리     143       하락 8    -5.30%
# 9               아이비김영   2,535     상승 485   +23.66%
# 10                리노스   1,906     상승 116    +6.48%
# 11               케이웨더  18,620  상승 11,620  +166.00%
# 12               유비케어   6,470     상승 420    +6.94%
# 13             디딤이앤에프     602      상승 95   +18.74%
# 14            카나리아바이오   1,133     하락 133   -10.51%

# %%
len(tables)
# Out:
# 4

# %%
# 현재의 시간을 가지고 온다.
from datetime import datetime

# %%
now=datetime.now()
print(datetime.now())
# Out:
# 2024-02-22 16:06:01.315296

# %%
type(now)
# Out:
# datetime.datetime

# %%
date=now.strftime('%y/%m/%d %H:%M:%S')

# %%
for index in range(len(tables)):
    now=datetime.now()
    date=now.strftime('%y-%m-%d %H-%M-%S')
    # 컬럼에 들어갈 데이터를 만드는 구간
    th_list=tables[index].find('tr').find_all('th')

    _cols=[]

    for i in th_list:
        _cols.append(i.get_text())
    #print(_cols)
        
    tr_list=tables[index].find_all('tr')
        
    _values=[]

    for i in range(1, len(tr_list)):
        _val=[tr_list[i].find('th').get_text()]

        td_list=tr_list[i].find_all('td')

        for j in td_list:
            data=j.get_text().strip()
            _val.append(data)

        _values.append(_val)
    #print(_values)
    # 반복실행할 때마다 다른 변수에 데이터를 저장
    file_list=['거래상위','상승','하락','시가총액 상위']
    globals()[f'df_{index}']= pd.DataFrame(_values, columns=_cols)
    pd.DataFrame(_values,columns=_cols).to_csv(f'{file_list[index]}_{date}.csv')

# %%
globals()['__name__']
# Out:
# '__main__'

# %%
df_1 #0,1,2,3바꿔보면 해당하는 값으로 바뀜
# Out:
#          종목명      현재가       전일대비       등락률
# 0       케이웨더   18,620  상승 11,620  +166.00%
# 1       아센디오    1,508    상한가 348   +30.00%
# 2     하인크코리아    1,786    상한가 412   +29.99%
# 3        앤씨앤    2,060    상한가 475   +29.97%
# 4       다보링크    2,850    상한가 655   +29.84%
# 5         베셀      705    상한가 162   +29.83%
# 6       가온칩스  107,600  상승 22,700   +26.74%
# 7      아이비김영    2,535     상승 485   +23.66%
# 8       빛샘전자    6,350   상승 1,160   +22.35%
# 9   피에스케이홀딩스   41,400   상승 6,900   +20.00%
# 10    디딤이앤에프      602      상승 95   +18.74%
# 11       엔피디    2,830     상승 440   +18.41%
# 12     그린리소스   31,750   상승 4,350   +15.88%
# 13       디어유   37,700   상승 4,950   +15.11%
# 14  레이크머티리얼즈   21,450   상승 2,670   +14.22%

# %%
df_3.sort_values('등락률',ascending=False)
# Out:
#          종목명      현재가       전일대비     등락률
# 9       LG화학  483,000  하락 17,000  -3.40%
# 12     삼성SDI  396,000   하락 4,000  -1.00%
# 10     NAVER  200,500   하락 2,000  -0.99%
# 7       셀트리온  176,100     하락 900  -0.51%
# 5      삼성전자우   62,800     하락 300  -0.48%
# 8   POSCO홀딩스  436,000   하락 2,000  -0.46%
# 0       삼성전자   72,700     하락 300  -0.41%
# 3   삼성바이오로직스  820,000   하락 3,000  -0.36%
# 14       카카오   57,800     하락 200  -0.34%
# 1     SK하이닉스  155,500   상승 6,500  +4.36%
# 11      삼성물산  165,300   상승 4,000  +2.48%
# 6         기아  119,500   상승 2,700  +2.31%
# 4        현대차  244,500   상승 5,000  +2.09%
# 13      KB금융   65,300     상승 200  +0.31%
# 2   LG에너지솔루션  407,500     상승 500  +0.12%

# %%
df1=df_3.copy()

# %%
# df1의 등략률데이터를 숫자로 변경
# % 문자열을 삭제
# df1['등락률'][0].replace("%","")
df1['등락률']=df1['등락률'].str.rstrip('%').astype('float')

# %%
df1.sort_values('등락률',ascending=False)
# Out:
#          종목명      현재가       전일대비   등락률
# 1     SK하이닉스  155,500   상승 6,500  4.36
# 11      삼성물산  165,300   상승 4,000  2.48
# 6         기아  119,500   상승 2,700  2.31
# 4        현대차  244,500   상승 5,000  2.09
# 13      KB금융   65,300     상승 200  0.31
# 2   LG에너지솔루션  407,500     상승 500  0.12
# 14       카카오   57,800     하락 200 -0.34
# 3   삼성바이오로직스  820,000   하락 3,000 -0.36
# 0       삼성전자   72,700     하락 300 -0.41
# 8   POSCO홀딩스  436,000   하락 2,000 -0.46
# 5      삼성전자우   62,800     하락 300 -0.48
# 7       셀트리온  176,100     하락 900 -0.51
# 10     NAVER  200,500   하락 2,000 -0.99
# 12     삼성SDI  396,000   하락 4,000 -1.00
# 9       LG화학  483,000  하락 17,000 -3.40

# %%
df2=df_3.copy()

# %%
# 등락률의 -,+ 를 파생변수 등락을 생성하여 [상승, 하락, 보합]
df2['등락']=df2['등락률'].map(
    lambda x: "상승" if x[0] == '+' else("하락" if x[0] == '-' else '보합')
)

# %%
df2['등락률']=df2['등락률'].map(
    lambda x : float(x.strip('-' '+' '%'))
)

# %%
df2.sort_values(['등락','등락률'],ascending=False)
# Out:
#          종목명      현재가       전일대비   등락률  등락
# 9       LG화학  483,000  하락 17,000  3.40  하락
# 12     삼성SDI  396,000   하락 4,000  1.00  하락
# 10     NAVER  200,500   하락 2,000  0.99  하락
# 7       셀트리온  176,100     하락 900  0.51  하락
# 5      삼성전자우   62,800     하락 300  0.48  하락
# 8   POSCO홀딩스  436,000   하락 2,000  0.46  하락
# 0       삼성전자   72,700     하락 300  0.41  하락
# 3   삼성바이오로직스  820,000   하락 3,000  0.36  하락
# 14       카카오   57,800     하락 200  0.34  하락
# 1     SK하이닉스  155,500   상승 6,500  4.36  상승
# 11      삼성물산  165,300   상승 4,000  2.48  상승
# 6         기아  119,500   상승 2,700  2.31  상승
# 4        현대차  244,500   상승 5,000  2.09  상승
# 13      KB금융   65,300     상승 200  0.31  상승
# 2   LG에너지솔루션  407,500     상승 500  0.12  상승
