# %%
import pandas as pd
# Out:
# C:\Users\82105\AppData\Local\Temp\ipykernel_71584\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
uriage=pd.read_csv("../csv/uriage.csv")

# %%
uriage.head(10)
# Out:
#       purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02       상품A       100.0           김가온
# 1  2019-07-13 13:05     상 품 S         NaN           김우찬
# 2  2019-05-11 19:42     상 품 a         NaN           김유찬
# 3  2019-02-12 23:40       상품Z      2600.0           김재현
# 4   2019-04-22 3:09       상품a         NaN           김강현
# 5  2019-03-20 19:16       상품S      1900.0           김우진
# 6  2019-05-18 19:16      상품 a         NaN           김재준
# 7   2019-04-18 0:14       상품V      2200.0           김민혁
# 8  2019-01-10 15:51       상품O      1500.0           김선우
# 9  2019-01-28 10:47       상품A       100.0           김태윤

# %% [markdown]
# # 데이터의 정형화
# 1. item_name의 value들을 모두 대문자로 변경
#     - 문자열 내장함수에서 대문자로 변경하는 함수(upper())
# 2. item_name의 value의 문자 사이에 있는 공백을 제거
#     - 문자열 내장함수에서 문자열 좌우의 공백을 제거하는 함수 ( strip() )
#     - 문자열 내장함수에 문자 사이의 공백을 제거하는 함수 ( replce(" ", ""))

# %%
uriage['item_name'].value_counts()
# Out:
# item_name
# 상품A     133
# 상품R     133
# 상품S     133
# 상품P     132
# 상품C     130
#        ...
# 상품 H      1
# 상 품K      1
# 상 품T      1
# 상품 X      1
# 상 품P      1
# Name: count, Length: 99, dtype: int64

# %%
# series 데이터에서는 upper() 사용이 불가능
uriage['item_name'].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 uriage['item_name'].upper()
#
# File c:\Users\82105\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6293, in NDFrame.__getattr__(self, name)
#    6286 if (
#    6287     name not in self._internal_names_set
#    6288     and name not in self._metadata
#    6289     and name not in self._accessors
#    6290     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291 ):
#    6292     return self[name]
# -> 6293 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
uriage.loc[2, 'item_name'].upper()
# Out:
# '상 품 A'

# %%
df=uriage.copy()

# %%
# case 1 (for문)
# 데이터프레임에서 item_name의 value를 하나씩 추출하여 upper()를 이용하여 대문자변환 후 비어있는 리스트에 추가
data_list=[]
for i in range(len(df)):
    # i가 의미하는 것은? -> 인덱스의 값/위치
    data=df.loc[i, 'item_name'].upper()
    data_list.append(data)

data_list

# %%
# 데이터프레임에서 item_name의 value를 하나씩 추출하여 대문자로 변환
for i in range(len(df)):
    data=df.loc[i,'item_name'].upper()
    # 해당하는 위치에 대이터를 대입
    df.loc[i,'item_name']=data

# %%
df.head(5)
# Out:
#       purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02       상품A       100.0           김가온
# 1  2019-07-13 13:05     상 품 S         NaN           김우찬
# 2  2019-05-11 19:42     상 품 A         NaN           김유찬
# 3  2019-02-12 23:40       상품Z      2600.0           김재현
# 4   2019-04-22 3:09       상품A         NaN           김강현

# %%
# 데이터프레임에서 item_name의 value를 하나씩 추출하여 대문자로 변환&공백제거
for i in range(len(df)):
    data=df.loc[i,'item_name'].upper().replace(" ","")
    # 해당하는 위치에 대이터를 대입
    df.loc[i,'item_name']=data

# %%
df.head(5)
# Out:
#       purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02       상품A       100.0           김가온
# 1  2019-07-13 13:05       상품S         NaN           김우찬
# 2  2019-05-11 19:42       상품A         NaN           김유찬
# 3  2019-02-12 23:40       상품Z      2600.0           김재현
# 4   2019-04-22 3:09       상품A         NaN           김강현

# %%
df['item_name'].value_counts()
# Out:
# item_name
# 상품S    140
# 상품A    139
# 상품R    136
# 상품P    135
# 상품V    134
# 상품C    133
# 상품F    126
# 상품D    125
# 상품Q    125
# 상품O    124
# 상품W    121
# 상품N    119
# 상품T    117
# 상품J    116
# 상품X    116
# 상품I    114
# 상품B    113
# 상품M    113
# 상품L    110
# 상품G    110
# 상품K    109
# 상품H    109
# 상품U    107
# 상품E    105
# 상품Y    102
# 상품Z      1
# Name: count, dtype: int64

# %%
# 특정 1차원 데이터에서 중복된 데이터를 제거
_list=df['item_name'].to_list()

# %%
_list2=['A','B','A','C']

# 리스트에서 중복된 데이터를 제거하고 새로운 리스트 생성
_list3=[]

for i in range(len(_list2)):
    # i가 의미하는 것은? list의 인덱스
    # print(i)
    # print(_list2[i])
    # _list3에 _list2[i]이 존재하지 않는다면?
    if _list2[i] not in _list3:
        _list3.append(_list2[i])
_list3
# Out:
# ['A', 'B', 'C']

# %%
_list4=[]
for i in _list2:
    if i not in _list4:
      _list4.append(i)
_list4
# Out:
# ['A', 'B', 'C']

# %%
# 집합 형태의 데이터 변환
list(set(_list2))
# Out:
# ['C', 'B', 'A']

# %%
# map() 함수
# map( 함수(내장함수, 일반함수, 람다함수), 1차원 데이터 )
def change(x):
    return x.lower()

list(map(
    change,
    _list2
))
# Out:
# ['a', 'b', 'a', 'c']

# %%
# map을 for문으로 구현
_list5=[]
for i in _list2:
    data=change(i)
    _list5.append(data)
_list5
# Out:
# ['a', 'b', 'a', 'c']

# %%
# map+lambda
list(map(lambda x:x.lower(),_list2))
# Out:
# ['a', 'b', 'a', 'c']

# %%
df2=uriage.copy()

# %%
df2.head(5)
# Out:
#       purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02       상품A       100.0           김가온
# 1  2019-07-13 13:05     상 품 S         NaN           김우찬
# 2  2019-05-11 19:42     상 품 a         NaN           김유찬
# 3  2019-02-12 23:40       상품Z      2600.0           김재현
# 4   2019-04-22 3:09       상품a         NaN           김강현

# %%
# map 함수를 이용하여 공백제거, 대문자변환
df2['item_name']

def change(x):
    # print(type(x))
    return x.upper().replace(" ","")
list(map(change, df2['item_name']))
# Out:
# ['상품A',
#  '상품S',
#  '상품A',
#  '상품Z',
#  '상품A',
#  '상품S',
#  '상품A',
#  '상품V',
#  '상품O',
#  '상품A',
#  '상품U',
#  '상품L',
#  '상품V',
#  '상품O',
#  '상품A',
#  '상품C',
#  '상품V',
#  '상품I',
#  '상품R',
#  '상품X',
#  '상품O',
#  '상품G',
#  '상품X',
#  '상품R',
#  '상품P',
#  '상품Q',
#  '상품Y',
#  '상품P',
#  '상품P',
#  '상품R',
#  '상품P',
#  '상품A',
#  '상품N',
#  '상품R',
#  '상품W',
#  '상품A',
#  '상품E',
#  '상품K',
#  '상품O',
#  '상품W',
#  '상품O',
#  '상품K',
#  '상품B',
#  '상품F',
#  '상품P',
#  '상품X',
#  '상품B',
#  '상품S',
#  '상품F',
#  '상품X',
#  '상품W',
#  '상품N',
#  '상품Q',
#  '상품P',
#  '상품I',
#  '상품F',
#  '상품D',
#  '상품R',
#  '상품M',
#  '상품M',
#  '상품Q',
#  '상품A',
#  '상품Y',
#  '상품I',
#  '상품U',
#  '상품H',
#  '상품P',
#  '상품P',
#  '상품T',
#  '상품Y',
#  '상품W',
#  '상품M',
#  '상품V',
#  '상품D',
#  '상품J',
#  '상품O',
#  '상품L',
#  '상품F',
#  '상품U',
#  '상품N',
#  '상품P',
#  '상품S',
#  '상품X',
#  '상품O',
#  '상품V',
#  '상품K',
#  '상품N',
#  '상품I',
#  '상품O',
#  '상품R',
#  '상품V',
#  '상품Y',
#  '상품E',
#  '상품E',
#  '상품H',
#  '상품S',
#  '상품W',
#  '상품Y',
#  '상품O',
#  '상품F',
#  '상품K',
#  '상품B',
#  '상품W',
#  '상품Q',
#  '상품Q',
#  '상품N',
#  '상품S',
#  '상품M',
#  '상품I',
#  '상품T',
#  '상품I',
#  '상품H',
#  '상품Y',
#  '상품R',
#  '상품C',
#  '상품V',
#  '상품T',
#  '상품A',
#  '상품T',
#  '상품Q',
#  '상품P',
#  '상품W',
#  '상품I',
#  '상품T',
#  '상품G',
#  '상품N',
#  '상품U',
#  '상품S',
#  '상품U',
#  '상품M',
#  '상품A',
#  '상품P',
#  '상품U',
#  '상품X',
#  '상품I',
#  '상품U',
#  '상품X',
#  '상품L',
#  '상품F',
#  '상품G',
#  '상품D',
#  '상품X',
#  '상품U',
#  '상품N',
#  '상품C',
#  '상품W',
#  '상품S',
#  '상품U',
#  '상품K',
#  '상품G',
#  '상품Q',
#  '상품I',
#  '상품L',
#  '상품T',
#  '상품P',
#  '상품T',
#  '상품V',
#  '상품E',
#  '상품P',
#  '상품G',
#  '상품L',
#  '상품P',
#  '상품M',
#  '상품D',
#  '상품O',
#  '상품N',
#  '상품X',
#  '상품W',
#  '상품J',
#  '상품X',
#  '상품R',
#  '상품A',
#  '상

#  '상품O',
#  '상품W',
#  '상품D',
#  '상품K',
#  '상품J',
#  '상품X',
#  '상품J',
#  '상품C',
#  '상품V',
#  '상품C',
#  '상품D',
#  '상품H',
#  '상품O',
#  '상품K',
#  '상품U',
#  '상품N',
#  '상품E',
#  '상품D',
#  '상품Y',
#  '상품B',
#  '상품G',
#  '상품X',
#  '상품X',
#  '상품B',
#  '상품S',
#  '상품T',
#  '상품O',
#  '상품W',
#  '상품Q',
#  '상품M',
#  '상품Q',
#  '상품O',
#  '상품J',
#  '상품B',
#  '상품K',
#  '상품S',
#  '상품F',
#  '상품C',
#  '상품O',
#  '상품S',
#  '상품T',
#  '상품H',
#  '상품R',
#  '상품P',
#  '상품A',
#  '상품U',
#  '상품H',
#  '상품J',
#  '상품S',
#  '상품A',
#  '상품Q',
#  '상품G',
#  '상품P',
#  '상품Q',
#  '상품R',
#  '상품X',
#  '상품Y',
#  '상품R',
#  '상품P',
#  '상품Q',
#  '상품I',
#  '상품D',
#  '상품F',
#  '상품X',
#  '상품Y',
#  '상품O',
#  '상품D',
#  '상품S',
#  '상품O',
#  '상품F',
#  '상품S',
#  '상품F',
#  '상품G',
#  '상품T',
#  '상품J',
#  '상품B',
#  '상품O',
#  '상품M',
#  '상품O',
#  '상품O',
#  '상품F',
#  '상품J',
#  '상품V',
#  '상품I',
#  '상품S',
#  '상품H',
#  '상품C',
#  '상품I',
#  '상품B',
#  '상품W',
#  '상품J',
#  '상품B',
#  ...]

# %%
df2['item_name'].map(change)
# Out:
# 0       상품A
# 1       상품S
# 2       상품A
# 3       상품Z
# 4       상품A
#        ...
# 2994    상품Y
# 2995    상품M
# 2996    상품Q
# 2997    상품H
# 2998    상품D
# Name: item_name, Length: 2999, dtype: object

# %%
df2['item_name'].map(lambda x:x.upper().replace(" ",""))
# Out:
# 0       상품A
# 1       상품S
# 2       상품A
# 3       상품Z
# 4       상품A
#        ...
# 2994    상품Y
# 2995    상품M
# 2996    상품Q
# 2997    상품H
# 2998    상품D
# Name: item_name, Length: 2999, dtype: object

# %%
df2['item_name'].replace(" ","")
# Out:
# 0         상품A
# 1       상 품 S
# 2       상 품 a
# 3         상품Z
# 4         상품a
#         ...
# 2994      상품Y
# 2995      상품M
# 2996      상품Q
# 2997      상품H
# 2998      상품D
# Name: item_name, Length: 2999, dtype: object

# %%
a = "Hello"

for i in a(0,1):
    print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 a = "Hello"
# ----> 3 for i in a(0,1):
#       4     print(a)
#
# TypeError: 'str' object is not callable

# %%
def custom_replace(data,origin, new):
    # 첫번째 매개변수는 변경시킬 문자열
    # 두번째 매개변수는 기존 문자열
    # 세번째 매개변수는 기존의 문자열을 변경할 문자열
    result=""
    for i in data:
        if i == origin:
            result += new
        else:
            result += i
    return result

# %%
custom_replace('abcde','a','A')
# Out:
# 'Abcde'

# %%
def custom_replace2(data,origin,new):
    result=[]
    for i in data:
        if i == origin:
            result.append(new)
        else:
            result.append(1)
    return result

# %%
data=['a','b','c','d']
custom_replace2(data, 'a', 'A')
# Out:
# ['A', 1, 1, 1]

# %%
data2=['abcd','efg']
custom_replace2(data2, 'a', 'A')
# Out:
# [1, 1]

# %%
df2['item_name'].replace('상품A',"A")
# Out:
# 0           A
# 1       상 품 S
# 2       상 품 a
# 3         상품Z
# 4         상품a
#         ...
# 2994      상품Y
# 2995      상품M
# 2996      상품Q
# 2997      상품H
# 2998      상품D
# Name: item_name, Length: 2999, dtype: object

# %%
df2['item_name']=df2['item_name'].str.upper().str.replace(" ","")

# %%
# 중복 데이터 제거
df2['item_name'].unique()
# Out:
# array(['상품A', '상품S', '상품Z', '상품V', '상품O', '상품U', '상품L', '상품C', '상품I',
#        '상품R', '상품X', '상품G', '상품P', '상품Q', '상품Y', '상품N', '상품W', '상품E',
#        '상품K', '상품B', '상품F', '상품D', '상품M', '상품H', '상품T', '상품J'],
#       dtype=object)

# %%
import numpy as np

# %%
# item_name이 상품A이고 item_price가 결측치가 아닌 데이터 필터
flag=df['item_name']=='상품A'
flag_null=df['item_price'].isna()
df.loc[flag & flag_null, ]
# Out:
#          purchase_date item_name  item_price customer_name
# 2     2019-05-11 19:42       상품A         NaN           김유찬
# 4      2019-04-22 3:09       상품A         NaN           김강현
# 6     2019-05-18 19:16       상품A         NaN           김재준
# 14    2019-06-11 12:57       상품A         NaN           김재호
# 300   2019-04-06 11:06       상품A         NaN           김태인
# 361    2019-01-21 3:33       상품A         NaN           김진우
# 667   2019-03-16 17:23       상품A         NaN           김주원
# 838    2019-06-24 5:06       상품A         NaN           김시호
# 844    2019-03-15 9:14       상품A         NaN           김강현
# 957   2019-07-19 14:12       상품A         NaN           김서윤
# 1260  2019-01-15 22:59       상품A         NaN           김하진
# 1394  2019-07-07 21:49       상품A         NaN           김은우
# 1474   2019-04-11 2:22       상품A         NaN           김선우
# 1892   2019-07-31 1:32       상품A         NaN           김윤찬
# 1937   2019-02-13 7:28       상품A         NaN           김시환
# 1977   2019-02-28 4:11       상품A         NaN           김서준
# 2063  2019-05-25 12:51       상품A         NaN           김재민
# 2278   2019-07-14 3:39       상품A         NaN           김시우
# 2636  2019-03-09 14:20       상품A         NaN           김우찬
# 2669  2019-03-05 20:21       상품A         NaN           김주혁
# 2732  2019-01-28 22:13       상품A         NaN           김윤호
# 2821  2019-06-21 11:09       상품A         NaN           김승훈

# %%
flag=df['item_name']=='상품A'
flag_null=df['item_price'].isna()
df.loc[flag & ~flag_null, ]
# Out:
#          purchase_date item_name  item_price customer_name
# 0     2019-06-13 18:02       상품A       100.0           김가온
# 9     2019-01-28 10:47       상품A       100.0           김태윤
# 31    2019-06-29 10:01       상품A       100.0           김하민
# 35     2019-01-12 3:26       상품A       100.0           김건희
# 61    2019-02-11 17:00       상품A       100.0           김성윤
# ...                ...       ...         ...           ...
# 2875  2019-06-03 17:33       상품A       100.0           김서진
# 2886  2019-04-25 17:15       상품A       100.0           김강현
# 2897  2019-05-20 14:05       상품A       100.0           김지안
# 2951   2019-05-06 2:24       상품A       100.0           김주혁
# 2973  2019-07-13 21:38       상품A       100.0           김태윤
#
# [117 rows x 4 columns]

# %% [markdown]
# # 결측치를 다른 값들로 대체
# 1. 상품명에 따라 가격이 고정값을 이룬다
# 2. 결측치를 상품명에 맞춰서 해당 상품의 결측치가 아닌 상품 가격들의 평균값을 대체
#
#     - ex) 상품A인 데이터 중 item_price가 결측치가 아닌 데이터들의 평균 값을 구하고 해당 값은 상품A의 데이터 중 item_price가 결측치인 부분에 대입

# %%
flag=df['item_name']=='상품A'
flag_null=df['item_price'].isna()

# %%
# 상품 A이고 가격이 결측치가 아닌 데이터
a_mean=df.loc[flag&~flag_null, 'item_price'].mean()

# %%
# 상품 A이고 가격이 결측치인 데이터 확인후 fillna로 결측치 채우기
# df.loc[flag&flag_null, ].fillna(a_mean)
df.loc[flag & flag_null, 'item_price']=a_mean

# %%
df.loc[flag&flag_null, ]
# Out:
#          purchase_date item_name  item_price customer_name
# 2     2019-05-11 19:42       상품A       100.0           김유찬
# 4      2019-04-22 3:09       상품A       100.0           김강현
# 6     2019-05-18 19:16       상품A       100.0           김재준
# 14    2019-06-11 12:57       상품A       100.0           김재호
# 300   2019-04-06 11:06       상품A       100.0           김태인
# 361    2019-01-21 3:33       상품A       100.0           김진우
# 667   2019-03-16 17:23       상품A       100.0           김주원
# 838    2019-06-24 5:06       상품A       100.0           김시호
# 844    2019-03-15 9:14       상품A       100.0           김강현
# 957   2019-07-19 14:12       상품A       100.0           김서윤
# 1260  2019-01-15 22:59       상품A       100.0           김하진
# 1394  2019-07-07 21:49       상품A       100.0           김은우
# 1474   2019-04-11 2:22       상품A       100.0           김선우
# 1892   2019-07-31 1:32       상품A       100.0           김윤찬
# 1937   2019-02-13 7:28       상품A       100.0           김시환
# 1977   2019-02-28 4:11       상품A       100.0           김서준
# 2063  2019-05-25 12:51       상품A       100.0           김재민
# 2278   2019-07-14 3:39       상품A       100.0           김시우
# 2636  2019-03-09 14:20       상품A       100.0           김우찬
# 2669  2019-03-05 20:21       상품A       100.0           김주혁
# 2732  2019-01-28 22:13       상품A       100.0           김윤호
# 2821  2019-06-21 11:09       상품A       100.0           김승훈

# %%
def fill_price(_df, _name):
    # _df를 copy() 복사한다.
    result=_df.copy()
    flag =result['item_name']==_name
    flag_null=result['item_price'].isna()

    # flag의 flag_null의 부정이 모두 만족하는 item_price의 평균
    mean_data=result.loc[flag & ~flag_null, 'item_price'].mean()
    # 위에서 구해진 평균 데이터를 flag와 flag_null을 모두 만족하는 item_price에 대입
    result.loc[flag&flag_null, 'item_price']=mean_data

    return result

# %%
name_list=set(df['item_name'])

# %%
for name in name_list:
    df= fill_price(df, name)

# %%
df.isna().sum()
# Out:
# purchase_date    0
# item_name        0
# item_price       0
# customer_name    0
# dtype: int64

# %%
df.loc[df['item_name']=='상품B','item_price'].mean()
# Out:
# 200.0

# %%
df[['item_name','item_price']].groupby('item_name').mean()
# Out:
#            item_price
# item_name
# 상품A             100.0
# 상품B             200.0
# 상품C             300.0
# 상품D             400.0
# 상품E             500.0
# 상품F             600.0
# 상품G             700.0
# 상품H             800.0
# 상품I             900.0
# 상품J            1000.0
# 상품K            1100.0
# 상품L            1200.0
# 상품M            1300.0
# 상품N            1400.0
# 상품O            1500.0
# 상품P            1600.0
# 상품Q            1700.0
# 상품R            1800.0
# 상품S            1900.0
# 상품T            2000.0
# 상품U            2100.0
# 상품V            2200.0
# 상품W            2300.0
# 상품X            2400.0
# 상품Y            2500.0
# 상품Z            2600.0

# %%
group_data=df[['item_name','item_price']].groupby('item_name')

# %%
group_data.get_group('상품A')
# Out:
#      item_name  item_price
# 0          상품A       100.0
# 2          상품A       100.0
# 4          상품A       100.0
# 6          상품A       100.0
# 9          상품A       100.0
# ...        ...         ...
# 2875       상품A       100.0
# 2886       상품A       100.0
# 2897       상품A       100.0
# 2951       상품A       100.0
# 2973       상품A       100.0
#
# [139 rows x 2 columns]

# %%
uriage['item_name']=uriage['item_name'].str.upper().str.replace(" ","")
uriage
# Out:
#          purchase_date item_name  item_price customer_name
# 0     2019-06-13 18:02       상품A       100.0           김가온
# 1     2019-07-13 13:05       상품S         NaN           김우찬
# 2     2019-05-11 19:42       상품A         NaN           김유찬
# 3     2019-02-12 23:40       상품Z      2600.0           김재현
# 4      2019-04-22 3:09       상품A         NaN           김강현
# ...                ...       ...         ...           ...
# 2994   2019-02-15 2:56       상품Y      2500.0           김정민
# 2995   2019-06-22 4:03       상품M      1300.0           김재원
# 2996  2019-03-29 11:14       상품Q         NaN           김지율
# 2997  2019-07-14 12:56       상품H         NaN           김승주
# 2998   2019-07-21 0:31       상품D       400.0           정준기
#
# [2999 rows x 4 columns]

# %%
# 정렬을 item_name을 기준으로 변경 오름차순 정렬
uriage.sort_values(['item_name','item_price'], inplace=True)

# %%
uriage.loc[ uriage['item_price']>0, ]
# Out:
#          purchase_date item_name  item_price customer_name
# 0     2019-06-13 18:02       상품A       100.0           김가온
# 9     2019-01-28 10:47       상품A       100.0           김태윤
# 31    2019-06-29 10:01       상품A       100.0           김하민
# 35     2019-01-12 3:26       상품A       100.0           김건희
# 61    2019-02-11 17:00       상품A       100.0           김성윤
# ...                ...       ...         ...           ...
# 2950  2019-03-03 13:01       상품Y      2500.0           김대현
# 2955  2019-04-30 22:13       상품Y      2500.0           정도형
# 2975  2019-07-21 10:36       상품Y      2500.0           김지오
# 2994   2019-02-15 2:56       상품Y      2500.0           김정민
# 3     2019-02-12 23:40       상품Z      2600.0           김재현
#
# [2612 rows x 4 columns]

# %%
uriage.reset_index(drop=True, inplace=True)

# %%
# 현재의 행의 item_prie가 결측치이고 전 행의 item_price가 결측치가 아닌
flag1=uriage['item_price'].isna()
# 전 행의 item_price가 결측치가 아닌 ~: 부정
flag2=~uriage['item_price'].shift(1).isna()

# %%
uriage.loc[flag1 & flag2, ]
# Out:
#          purchase_date item_name  item_price customer_name
# 117   2019-05-11 19:42       상품A         NaN           김유찬
# 234   2019-04-15 16:44       상품B         NaN           김지호
# 365   2019-02-12 22:35       상품C         NaN           김대현
# 500   2019-04-01 13:25       상품D         NaN           김유찬
# 602   2019-02-20 23:12       상품E         NaN           김시온
# 722   2019-02-19 16:59       상품F         NaN           김주혁
# 837    2019-05-12 6:18       상품G         NaN           김시훈
# 952    2019-06-21 2:38       상품H         NaN           김준희
# 1060  2019-06-25 16:31       상품I         NaN           김재훈
# 1175   2019-06-20 9:00       상품J         NaN           김연준
# 1282  2019-07-17 20:15       상품K         NaN           김은혁
# 1398  2019-06-10 18:21       상품L         NaN           김지한
# 1512   2019-06-16 0:41       상품M         NaN           김태민
# 1625  2019-04-24 17:44       상품N         NaN           김은율
# 1752  2019-07-02 21:30       상품O         NaN           김도현
# 1891  2019-01-04 12:05       상품P         NaN           김우진
# 2007   2019-05-21 5:04       상품Q         NaN           김승주
# 2144   2019-07-06 4:39       상품R         NaN           김도훈
# 2277  2019-07-13 13:05       상품S         NaN           김우찬
# 2406   2019-07-05 1:18       상품T         NaN           김지완
# 2514  2019-04-19 13:27       상품U         NaN           김우빈
# 2636   2019-05-07 7:37       상품V         NaN           김지훈
# 2758  2019-02-04 18:23       상품W         NaN           김시윤
# 2879   2019-03-24 1:13       상품X         NaN           김태현
# 2984  2019-05-10 17:54       상품Y         NaN           김태민

# %%
uriage['item_price']=uriage['item_price'].fillna(method='ffill')
# Out:
# C:\Users\82105\AppData\Local\Temp\ipykernel_71584\3258419248.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   uriage['item_price']=uriage['item_price'].fillna(method='ffill')

# %%
uriage.isna().sum()
# Out:
# purchase_date    0
# item_name        0
# item_price       0
# customer_name    0
# dtype: int64

# %%
uriage[['item_name','item_price']].groupby('item_name').mean()
# Out:
#            item_price
# item_name
# 상품A             100.0
# 상품B             200.0
# 상품C             300.0
# 상품D             400.0
# 상품E             500.0
# 상품F             600.0
# 상품G             700.0
# 상품H             800.0
# 상품I             900.0
# 상품J            1000.0
# 상품K            1100.0
# 상품L            1200.0
# 상품M            1300.0
# 상품N            1400.0
# 상품O            1500.0
# 상품P            1600.0
# 상품Q            1700.0
# 상품R            1800.0
# 상품S            1900.0
# 상품T            2000.0
# 상품U            2100.0
# 상품V            2200.0
# 상품W            2300.0
# 상품X            2400.0
# 상품Y            2500.0
# 상품Z            2600.0
